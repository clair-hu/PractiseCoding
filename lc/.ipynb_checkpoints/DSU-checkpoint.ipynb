# %%
class DSU:
    def __init__(self, N):
        self.par = range(N)
        
    def find(self, x):
        if self.par[x] != x:
            self.par[x] = self.find(self.par[x])
        return self.par[x]
    
    def union(self, x, y):
        xr = self.find(x)
        yr = self.find(y)
        self.par[xr] = yr
        
        
# class Solution:
#     def regionsBySlashes(self, grid):
#         length = len(grid)
#         dsu = DSU((4 * length)**2)
#         for r, row in enumerate(grid):
#             for c, val in enumerate(row):
#                 root = 4 * (r * length + c)
#                 if val in '/':
                    
        
        
        
#         print(grid)
#         import collections
#         graph = collections.defaultdict(set)
#         length = len(grid)
#         # initialized the square
#         for i in range(length):
#             graph[(i, 0)].add((i+1, 0))
#             graph[(i+1, 0)].add((i, 0))
#             graph[(0, i)].add((0, i+1))
#             graph[(0, i+1)].add((0, i))
#             graph[(i, length)].add((i+1, length))
#             graph[(i+1, length)].add((i, length))
#             graph[(length, i)].add((length, i+1))
#             graph[(length, i+1)].add((length, i))
        
#         for r, row in enumerate(grid):
#             i = 0
#             while i < len(row):
#                 if row[i] == "\\":
#                     graph[(r, i)].add((r+1, i+1))
#                     graph[(r+1, i+1)].add((r, i))
#                 elif row[i] == "/":
#                     graph[(r, i+1)].add((r+1, i))
#                     graph[(r+1, i)].add((r, i+1))
#                 i += 1
#         print(graph)
        
        
#         def DFS(node, path, output, visited):
#             for node in graph:
#                 if node and len(graph[node]) > 0 and node not in visited:
#                     visited.add(node)
#                     if node in path and not any(path <= o or o <= path for o in output):
#                         output.add(path)
#                     path.add(node)
                    
        
                

s = Solution()
input = [
  "\\/",
  "/ "
]
s.regionsBySlashes(input)
