# %%
# Receive stream of events
# 	-event is an http request containing event id, timestamp, tag
# 	-tag is a string
# Users care about number of events for tags they are interested in
# 	-interested in number of events aggregated per hour
# 	-want to get these reports weekly (each hour of the week will be a single row of the report)

# User Bob is interested in tags A, B, C
# hour 1: 5 events
# hour 2: 2 events
# hour 3: 4 events

# User Alice is interested in tags C, D
# hour 1: 2 events
# hour 2: 4 events

100M per day
10k TPS

# Design a platform where users can specify tags they are interested in and then receive weekly reports on those tags

# billions of events per day
# millions of unique tags

# print("Hello")

# int = 4
# res = 2

# int = 5
# res = 2 (floor)


# 10 digit: 2.2323232323
# 10.124000000000
#  /num = (output + delta)
# num = output**2 + 2*output*delta + delta**2
# num * 10**20 = output**2 * 10**20 + 2*output * 10**10
# math: (output * 10**10)**2 = output**2 * 10**20
def transform_10_digit(target):
  print((str(target)).split(".")[0])
  print((str(target)).split(".")[1][:10])
  return float((str(target)).split(".")[0] + "." + (str(target)).split(".")[1][:10])
  
a = transform_10_digit(1.234234242342423)
print(a)


def square_root(num):
  
  # def construct_output(target)
  
  
     
    5
    2
    2.1 2.2 2.3
    2.31 2.32
    
  
  def is_valid(target):
    # if len(str(target).split(".")[1]) == 10:
      # target = float()    
    # check whether the current target is with 10 digit
    return target ** 2 <= num and (target+10**(-10)) ** 2 > num
      
  
  left = 0
  right = num
  mid = left + (right - left) / 2
  while 0 <= mid <= num:
    print(left, mid, right)
    if is_valid(mid):
      return mid
    if mid ** 2 > num:
      right = mid
    else:
      left = mid
    mid = left + (right - left) / 2 
    # mid = 
    
  
num_0 = 5
res = square_root(num_0)
print(res)

# num_1 = 16
# res = square_root(num_1)
# print(res)

# num_2 = 20
# res = square_root(num_2)
# print(res)

# num_3 = 0
# res = square_root(num_3)
# print(res)
