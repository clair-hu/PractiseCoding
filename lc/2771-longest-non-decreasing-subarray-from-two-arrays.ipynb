# %%
#### not passed, time limit exceeded, memory limit exceeded
def maxNonDecreasingLength(num1, num2):
    res = [1]
    n = len(num1)

    @cache
    def rec(index, curr_len, prev_val):
        num1_val = num1[index]
        num2_val = num2[index]
        if index == n:
            res[0] = max(res[0], curr_len)
            return curr_len
        max_val, min_val = max(num1_val, num2_val), min(num1_val, num2_val)
        if min_val >= prev_val:
            rec(index+1, curr_len+1, min_val)
        if min_val < prev_val:
            rec(index+1, 1, min_val)
            res[0] = max(res[0], curr_len)
            if max_val >= prev_val:
                rec(index+1, curr_len+1, max_val)
        

    rec(1, 1, min(num1[0], num2[0]))
    return res[0]

# %%
### accepted, need to use lru_cache
class Solution:
    def maxNonDecreasingLength(self, nums1: List[int], nums2: List[int]) -> int:
        num1 = nums1
        num2 = nums2
        n = len(num1)
        results = [0]

        @lru_cache(None)
        def rec(index, prev_val):
            res = 0
            if index == n:
                return 0

            num1_val = num1[index]
            num2_val = num2[index]

            max_val, min_val = max(num1_val, num2_val), min(num1_val, num2_val)
            if min_val >= prev_val:
                res = 1 + rec(index+1, min_val)
            if min_val < prev_val:
                results[0] = max(rec(index, 0), results[0])
                if max_val >= prev_val:
                    res = 1 + rec(index+1, max_val)
            results[0] = max(results[0], res)
            return res
        
        return max(rec(0, 0), results[0])

import unittest
class MaxNonDecreasingLengthUnitTest(unittest.TestCase):
    def test_0(self):
        num1, num2 = [2,3,1], [1,2,1]
        expected = 2
        self.assertEqual(maxNonDecreasingLength(num1, num2), expected)

    def test_1(self):
        num1, num2 = [1,3,2,1], [2,2,3,4]
        expected = 4
        self.assertEqual(maxNonDecreasingLength(num1, num2), expected)

    def test_2(self):
        num1, num2 = [1,3,2,1], [2,2,3]
        expected = 3
        self.assertEqual(maxNonDecreasingLength(num1, num2), expected)

    def test_3(self):
        num1, num2 = [1,3,2], [2,2,3,4]
        expected = 4
        self.assertEqual(maxNonDecreasingLength(num1, num2), expected)


if __name__ == "__main__":
    unittest.main()
# Out:
# usage: ipykernel_launcher.py [-h] [-v] [-q] [--locals] [-f] [-c] [-b]
#                              [-k TESTNAMEPATTERNS]
#                              [tests ...]
# ipykernel_launcher.py: error: argument -f/--failfast: ignored explicit argument '/Users/clairhu/Library/Jupyter/runtime/kernel-v2-50152x0B6qF81WrlM.json'
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/argparse.py:1851, in ArgumentParser.parse_known_args(self, args, namespace)
#    1850 try:
# -> 1851     namespace, args = self._parse_known_args(args, namespace)
#    1852 except ArgumentError:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/argparse.py:2060, in ArgumentParser._parse_known_args(self, arg_strings, namespace)
# ...

# %%
### unit test generated by ai assistant
import unittest
from typing import List

class Solution:
    def maxNonDecreasingLength(self, nums1: List[int], nums2: List[int]) -> int:
        # The implementation of the maxNonDecreasingLength function goes here
        pass

class TestSolution(unittest.TestCase):
    def test_max_non_decreasing_length(self):
        solution = Solution()

        # Test case 1
        nums1 = [1, 2, 3, 4, 5]
        nums2 = [6, 7, 8, 9, 10]
        expected_output = 5
        self.assertEqual(solution.maxNonDecreasingLength(nums1, nums2), expected_output)

        # Test case 2
        nums1 = [1, 2, 3, 4, 5]
        nums2 = [1, 2, 3, 4, 5]
        expected_output = 5
        self.assertEqual(solution.maxNonDecreasingLength(nums1, nums2), expected_output)

        # Test case 3
        nums1 = [1, 2, 3, 4, 5]
        nums2 = [5, 4, 3, 2, 1]
        expected_output = 5
        self.assertEqual(solution.maxNonDecreasingLength(nums1, nums2), expected_output)

        # Test case 4
        nums1 = [1, 3, 5, 7, 9]
        nums2 = [2, 4, 6, 8, 10]
        expected_output = 5
        self.assertEqual(solution.maxNonDecreasingLength(nums1, nums2), expected_output)

        # Test case 5
        nums1 = [1, 1, 1, 1, 1]
        nums2 = [1, 1, 1, 1, 1]
        expected_output = 5
        self.assertEqual(solution.maxNonDecreasingLength(nums1, nums2), expected_output)

if __name__ == '__main__':
    unittest.main()
